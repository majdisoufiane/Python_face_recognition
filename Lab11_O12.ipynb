# %% [markdown]
# # Lab11

# %%
print("hello")
# Out:
# hello

# %%
from random import choice 
list =[g1,g2,44]
print(choice[list])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5254de07ead0> in <module>
#       1 from random import choice
# ----> 2 list =[g1,g2,44]
#       3 print(choice[list])
#
# NameError: name 'g1' is not defined

# %%
from random import choice
from IPython.display import Image,display
list = ["g1","g2"]
name = choice(list)
print ("Name :",name)
display(Image(filename = "photos_o12/"+name+".jpg"))
# Out:
# Name : g1

# %%
from random import choice
from IPython.display import Image,display
list = ["g1","g2"]
name = choice(list)
print ("Name :",name)
display(Image(filename = "photos_o12/"+name+".jpg"))
# Out:
# Name : g1

# %%
from random import choice
from IPython.display import Image,display
list = 
name = choice(list)
print ("Name :",name)
display(Image(filename = "photos_o12/"+name+".jpg"))
# Out:
# Name : g2

# %%
from random import choice
from IPython.display import Image,display
list = 
name = choice(list)
print ("Name :",name)
display(Image(filename = "photos_o12/"+name+".jpg"))
# Out:
#   File "<ipython-input-1-67cc34666157>", line 3
#     list =
#            ^
# SyntaxError: invalid syntax

# %%
from random import choice
from IPython.display import Image,display
list = ["g1","g2"]
name = choice(list)
print ("Name :",name)
display(Image(filename = "photos_o12/"+name+".jpg"))
# Out:
# Name : g1

# %%
from random import choice
from IPython.display import Image,display
import glob 
list = glob.glob("photos_o12/*.jpg")
x = ''
while list and x != 'q' :
    path = choice(list)
    name = path.split('\\')[1].split('.')[0]
    print("path :"  ,path)
    print ("Name :" ,name)
    display(Image(filename = path ))
    list.remove(path)
    x= input("Entrer to continue or q to exit ")
print("------------END------------")
# Out:
# path : photos_o12\g1.jpg
# Name : g1
# Entrer to continue or q to exit q
# ------------END------------

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop petit ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 1
# trop petit
# entrer un nombre
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4f30a7e727d9> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
#       7     if ch < nb : print("trop petit ")
#       8     if ch > nb : print("trop petit ")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 5
# trop petit
# entrer un nombre 4
# trop petit
# entrer un nombre 50
# trop petit
# entrer un nombre 54
# trop petit
# entrer un nombre 78
# trop petit
# entrer un nombre 77
# trop petit
# entrer un nombre 99
# trop petit
# entrer un nombre 78
# trop petit
# entrer un nombre 22
# trop petit
# entrer un nombre 11
# trop petit
# entrer un nombre 1
# trop petit
# entrer un nombre 2
# trop petit
# entrer un nombre 3
# trop petit
# entrer un nombre 100
# trop petit
# entrer un nombre 66
# trop petit
# entrer un nombre 23
# trop petit
# entrer un nombre 10
# trop petit
# entrer un nombre 77
# trop petit
# entrer un nombre 99
# trop petit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4f30a7e727d9> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
# ...

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 22
# trop petit
# entrer un nombre 50
# trop grand
# entrer un nombre 23
# trop petit
# entrer un nombre 24
# trop petit
# entrer un nombre 25
# trop petit
# entrer un nombre 26
# trop petit
# entrer un nombre 27
# trop petit
# entrer un nombre 30
# trop petit
# entrer un nombre 40
# trop grand
# entrer un nombre 31
# trop petit
# entrer un nombre 32
# trop petit
# entrer un nombre 33
# vous avez trouve le nombr apres  12 essaie

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 10
# trop petit
# entrer un nombre 20
# trop petit
# entrer un nombre 30
# trop petit
# entrer un nombre 40
# trop petit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-73b270dbb08d> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
#       7     if ch < nb : print("trop petit ")
#       8     if ch > nb : print("trop grand ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
import random 
nb = random.randint(1,10)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")

# %%
1

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 25
# trop petit
# entrer un nombre 60
# trop grand
# entrer un nombre 30
# trop petit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-73b270dbb08d> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
#       7     if ch < nb : print("trop petit ")
#       8     if ch > nb : print("trop grand ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 88
# trop grand
# entrer un nombre 80
# trop grand
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-73b270dbb08d> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
#       7     if ch < nb : print("trop petit ")
#       8     if ch > nb : print("trop grand ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 40
# trop grand
# entrer un nombre 20
# trop petit
# entrer un nombre 30
# trop petit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-73b270dbb08d> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
#       7     if ch < nb : print("trop petit ")
#       8     if ch > nb : print("trop grand ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 64
# trop grand
# entrer un nombre 50
# trop petit
# entrer un nombre 5
# trop petit
# entrer un nombre 60
# trop grand
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-73b270dbb08d> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
#       7     if ch < nb : print("trop petit ")
#       8     if ch > nb : print("trop grand ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 100
# vous avez trouve le nombr apres  1 essaie

# %%
import random 
nb = random.randint(1,100)
ch = -1 
n=0
while nb != ch :
    ch = int(input("entrer un nombre "))
    if ch < nb : print("trop petit ")
    if ch > nb : print("trop grand ")
    n=n+1
print("vous avez trouve le nombr apres " ,n,"essaie")
# Out:
# entrer un nombre 1
# trop petit
# entrer un nombre 5
# trop petit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-73b270dbb08d> in <module>
#       4 n=0
#       5 while nb != ch :
# ----> 6     ch = int(input("entrer un nombre "))
#       7     if ch < nb : print("trop petit ")
#       8     if ch > nb : print("trop grand ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import face_recognation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-7d7b0f0e1568> in <module>
# ----> 1 import face_recognation
#
# ModuleNotFoundError: No module named 'face_recognation'

# %%
import face_recognition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-ca17cc6b8bdb> in <module>
# ----> 1 import face_recognition
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import face_recognition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ca17cc6b8bdb> in <module>
# ----> 1 import face_recognition
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
import cv2

# %%
import face_recognition

# %%
import face_recognition
import cv2
import numpy as np

# This is a demo of running face recognition on live video from your webcam. It's a little more complicated than the
# other example, but it includes some basic performance tweaks to make things run a lot faster:
#   1. Process each video frame at 1/4 resolution (though still display it at full resolution)
#   2. Only detect faces in every other frame of video.

# PLEASE NOTE: This example requires OpenCV (the `cv2` library) to be installed only to read from your webcam.
# OpenCV is *not* required to use the face_recognition library. It's only required if you want to run this
# specific demo. If you have trouble installing it, try any of the other demos that don't require it instead.

# Get a reference to webcam #0 (the default one)
video_capture = cv2.VideoCapture(0)

# Load a sample picture and learn how to recognize it.
obama_image = face_recognition.load_image_file("photos_o12/souf.jpg")
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]

# Load a second sample picture and learn how to recognize it.
biden_image = face_recognition.load_image_file("photos_o12/simo.jpg")
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]

# Create arrays of known face encodings and their names
known_face_encodings = [
    obama_face_encoding,
    biden_face_encoding
]
known_face_names = [
    "souf",
    "simo"
]

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True

while True:
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Resize frame of video to 1/4 size for faster face recognition processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_small_frame = small_frame[:, :, ::-1]

    # Only process every other frame of video to save time
    if process_this_frame:
        # Find all the faces and face encodings in the current frame of video
        face_locations = face_recognition.face_locations(rgb_small_frame)
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"

            # # If a match was found in known_face_encodings, just use the first one.
            # if True in matches:
            #     first_match_index = matches.index(True)
            #     name = known_face_names[first_match_index]

            # Or instead, use the known face with the smallest distance to the new face
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]

            face_names.append(name)

    process_this_frame = not process_this_frame


    # Display the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        # Scale back up face locations since the frame we detected in was scaled to 1/4 size
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    # Display the resulting image
    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release handle to the webcam
video_capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5544/1180701047.py in <module>
#      13
#      14 # Get a reference to webcam #0 (the default one)
# ---> 15 video_capture = cv2.VideoCapture(0)
#      16
#      17 # Load a sample picture and learn how to recognize it.
#
# KeyboardInterrupt:

# %%
import face_recognition
import cv2
import numpy as np

# This is a demo of running face recognition on live video from your webcam. It's a little more complicated than the
# other example, but it includes some basic performance tweaks to make things run a lot faster:
#   1. Process each video frame at 1/4 resolution (though still display it at full resolution)
#   2. Only detect faces in every other frame of video.

# PLEASE NOTE: This example requires OpenCV (the `cv2` library) to be installed only to read from your webcam.
# OpenCV is *not* required to use the face_recognition library. It's only required if you want to run this
# specific demo. If you have trouble installing it, try any of the other demos that don't require it instead.

# Get a reference to webcam #0 (the default one)
video_capture = cv2.VideoCapture(0)

# Load a sample picture and learn how to recognize it.
obama_image = face_recognition.load_image_file("photos_o12/soufiane.jpg")
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]

# Load a second sample picture and learn how to recognize it.
biden_image = face_recognition.load_image_file("photos_o12/simo.jpg")
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]

# Create arrays of known face encodings and their names
known_face_encodings = [
    obama_face_encoding,
    biden_face_encoding
]
known_face_names = [
    "soufiane",
    "simo"
]

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True

while True:
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Resize frame of video to 1/4 size for faster face recognition processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_small_frame = small_frame[:, :, ::-1]

    # Only process every other frame of video to save time
    if process_this_frame:
        # Find all the faces and face encodings in the current frame of video
        face_locations = face_recognition.face_locations(rgb_small_frame)
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"

            # # If a match was found in known_face_encodings, just use the first one.
            # if True in matches:
            #     first_match_index = matches.index(True)
            #     name = known_face_names[first_match_index]

            # Or instead, use the known face with the smallest distance to the new face
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]

            face_names.append(name)

    process_this_frame = not process_this_frame


    # Display the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        # Scale back up face locations since the frame we detected in was scaled to 1/4 size
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    # Display the resulting image
    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release handle to the webcam
video_capture.release()
cv2.destroyAllWindows()
